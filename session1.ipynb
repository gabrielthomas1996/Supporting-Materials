# %%
'''
THE FOLLOWING CODE HAS BEEN IMPLEMENTED FOLLOWING THE GUIDENCE OF THE SESSION TUTORIALS
DEPICTING CREATIVE APPLICATIONS OF DEEPLEARNING WITH TENSORFLOW AS PUBLISHED BY KADENZE

LINK:
https://www.kadenze.com/courses/creative-applications-of-deep-learning-with-tensorflow-iv/info

Creative Applications of Deep Learning w/ Tensorflow.
Kadenze, Inc.
Parag K. Mital

Copyright Parag K. Mital, June 2016.

'''

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# /Users/gabrielshannon/anaconda3/envs/env/lib/python3.6/site-packages/matplotlib/__init__.py:1003: UserWarning: Duplicate key in file "/Users/gabrielshannon/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /Users/gabrielshannon/anaconda3/envs/env/lib/python3.6/site-packages/matplotlib/__init__.py:1003: UserWarning: Duplicate key in file "/Users/gabrielshannon/.matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
from libs import utils
# utils.<tab>
files = utils.get_celeb_files()

# %%
img = plt.imread(files[50])
# img.<tab>
print(img)
# Out:
# [[[206 203 210]
#   [205 202 209]
#   [204 201 208]
#   ...
#   [218 216 227]
#   [219 216 227]
#   [219 216 227]]
#
#  [[206 203 210]
#   [205 202 209]
#   [204 201 208]
#   ...
#   [218 216 227]
#   [219 216 227]
#   [219 216 227]]
#
#  [[206 203 210]
#   [205 202 209]
#   [204 201 208]
#   ...
#   [218 216 227]
#   [219 216 227]
#   [219 216 227]]
#
#  ...
#
#  [[234 238 241]
#   [234 238 241]
#   [234 238 241]
#   ...
#   [148 111  93]
#   [156 123 108]
#   [158 125 110]]
#
#  [[235 239 242]
#   [235 239 242]
#   [235 239 242]
#   ...
#   [144 107  89]
#   [162 128 116]
#   [154 120 108]]
#
#  [[235 239 242]
#   [235 239 242]
#   [235 239 242]
#   ...
#   [144 107  89]
#   [132  98  88]
#   [124  90  80]]]

# %%
plt.imshow(img)

# %%
img.shape
# (218, 178, 3)
# Out:
# (218, 178, 3)

# %%
plt.imshow(img[:, :, 0], cmap='gray')
plt.imshow(img[:, :, 1], cmap='gray')
plt.imshow(img[:, :, 2], cmap='gray')

# %%
imgs = utils.get_celeb_imgs()

# %%
plt.imshow(imgs[0])

# %%
imgs[0].shape
# Out:
# (218, 178, 3)

# %%
data = np.array(imgs)
data.shape
# Out:
# (99, 218, 178, 3)

# %%
mean_img = np.mean(data, axis=0)
plt.imshow(mean_img.astype(np.uint8))

# %%
std_img = np.std(data, axis=0)
plt.imshow(std_img.astype(np.uint8))

# %%
plt.imshow(np.mean(std_img, axis=2).astype(np.uint8))

# %%
flattened = data.ravel()
print(data[:1])
print(flattened[:10])
# Out:
# [[[[186 168 166]
#    [181 166 163]
#    [180 166 163]
#    ...
#    [173 156 149]
#    [188 173 170]
#    [139 124 121]]
#
#   [[186 168 166]
#    [181 166 163]
#    [180 166 163]
#    ...
#    [167 150 143]
#    [187 172 169]
#    [144 129 126]]
#
#   [[186 168 166]
#    [181 166 163]
#    [179 165 162]
#    ...
#    [154 137 130]
#    [181 166 163]
#    [149 134 131]]
#
#   ...
#
#   [[253 248 254]
#    [253 248 254]
#    [253 248 254]
#    ...
#    [108  59  42]
#    [ 91  64  35]
#    [ 91  64  35]]
#
#   [[253 248 254]
#    [253 248 254]
#    [253 248 254]
#    ...
#    [100  53  35]
#    [ 82  55  26]
#    [ 87  60  31]]
#
#   [[253 248 254]
#    [253 248 254]
#    [253 248 254]
#    ...
#    [ 99  54  35]
#    [ 82  55  26]
#    [ 87  60  31]]]]
# [186 168 166 181 166 163 180 166 163 183]

# %%
plt.hist(flattened.ravel(), 255)
# Out:
# (array([216775., 117809.,  99108.,  71029.,  66458.,  62040.,  62490.,
#          58050.,  56635.,  56059.,  56780.,  58474.,  63103.,  60999.,
#          59056.,  59178.,  62372.,  63435.,  62114.,  64891.,  63209.,
#          61808.,  61239.,  60546.,  60260.,  60094.,  58868.,  59083.,
#          60100.,  64522.,  66939.,  61287.,  58979.,  58931.,  59421.,
#          58662.,  58251.,  58246.,  58038.,  57472.,  55689.,  56041.,
#          55120.,  59011.,  61573.,  56502.,  55932.,  55463.,  54890.,
#          57000.,  54204.,  53235.,  52873.,  50631.,  49665.,  47534.,
#          46438.,  45243.,  44577.,  43038.,  42202.,  41856.,  41687.,
#          41135.,  41822.,  42248.,  42559.,  42673.,  43015.,  43088.,
#          42965.,  42493.,  41981.,  42000.,  41742.,  41560.,  42536.,
#          42189.,  42173.,  42106.,  42297.,  42300.,  42378.,  42066.,
#          42286.,  41725.,  41879.,  41385.,  40967.,  40831.,  41561.,
# ...

# %%
plt.hist(mean_img.ravel(), 255)
# Out:
# (array([1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 6.000e+00,
#         2.000e+01, 2.900e+01, 2.300e+01, 4.400e+01, 4.600e+01, 4.400e+01,
#         3.900e+01, 4.700e+01, 5.200e+01, 4.000e+01, 5.900e+01, 4.800e+01,
#         7.200e+01, 7.500e+01, 8.500e+01, 8.000e+01, 9.000e+01, 9.400e+01,
#         1.180e+02, 1.260e+02, 1.130e+02, 1.290e+02, 1.210e+02, 1.640e+02,
#         2.020e+02, 2.460e+02, 2.450e+02, 2.530e+02, 3.120e+02, 3.250e+02,
#         3.310e+02, 3.350e+02, 3.760e+02, 3.860e+02, 3.810e+02, 4.140e+02,
#         4.510e+02, 4.880e+02, 5.330e+02, 5.730e+02, 6.480e+02, 7.010e+02,
#         7.770e+02, 7.760e+02, 8.200e+02, 8.070e+02, 8.670e+02, 8.710e+02,
#         8.940e+02, 8.600e+02, 8.250e+02, 8.220e+02, 8.470e+02, 8.970e+02,
#         8.780e+02, 8.860e+02, 8.100e+02, 8.440e+02, 8.920e+02, 8.840e+02,
#         9.110e+02, 9.180e+02, 8.960e+02, 9.250e+02, 9.320e+02, 9.370e+02,
#         9.330e+02, 9.450e+02, 9.720e+02, 1.070e+03, 1.045e+03, 1.053e+03,
# ...

# %%
bins = 20
fig, axs = plt.subplots(1, 3, figsize=(12, 6), sharey=True, sharex=True)
axs[0].hist((data[0]).ravel(), bins)
axs[0].set_title('img distribution')
axs[1].hist((mean_img).ravel(), bins)
axs[1].set_title('mean distribution')
axs[2].hist((data[0] - mean_img).ravel(), bins)
axs[2].set_title('(img - mean) distribution')
# Out:
# Text(0.5, 1.0, '(img - mean) distribution')

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 6), sharey=True, sharex=True)
axs[0].hist((data[0] - mean_img).ravel(), bins)
axs[0].set_title('(img - mean) distribution')
axs[1].hist((std_img).ravel(), bins)
axs[1].set_title('std deviation distribution')
axs[2].hist(((data[0] - mean_img) / std_img).ravel(), bins)
axs[2].set_title('((img - mean) / std_dev) distribution')
# Out:
# Text(0.5, 1.0, '((img - mean) / std_dev) distribution')

# %%
import tensorflow as tf

# %%
x = np.linspace(-3.0, 3.0, 100)

#An array of 100 numbers equally spaced from -3.0 to 3.0.
print(x)

#numpy arrays have a `shape`, in this case a 1-dimensional array of 100 values
print(x.shape)

# and a `dtype`, in this case float64, or 64 bit floating point values.
print(x.dtype)
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
# ...

# %%
x = tf.linspace(-3.0, 3.0, 100)
print(x)
# Out:
# Tensor("LinSpace:0", shape=(100,), dtype=float32)

# %%
g = tf.get_default_graph()

# %%
[op.name for op in g.get_operations()]
# Out:
# ['LinSpace/start', 'LinSpace/stop', 'LinSpace/num', 'LinSpace']

# %%
g.get_tensor_by_name('LinSpace' + ':0')
# Out:
# <tf.Tensor 'LinSpace:0' shape=(100,) dtype=float32>

# %%
# create a session:
sess = tf.Session()

# tell session to compute anything created in the tensorflow graph.
computed_x = sess.run(x)
print(computed_x)

# Alternatively tell the previous Tensor to evaluate itself using this session:
computed_x = x.eval(session=sess)
print(computed_x)

# close session
sess.close()
# Out:
# [-3.         -2.939394   -2.878788   -2.8181818  -2.7575758  -2.6969697
#  -2.6363635  -2.5757575  -2.5151515  -2.4545455  -2.3939395  -2.3333333
#  -2.2727273  -2.2121212  -2.151515   -2.090909   -2.030303   -1.969697
#  -1.9090909  -1.8484848  -1.7878788  -1.7272727  -1.6666666  -1.6060605
#  -1.5454545  -1.4848485  -1.4242424  -1.3636363  -1.3030303  -1.2424242
#  -1.1818181  -1.121212   -1.060606   -1.         -0.939394   -0.87878776
#  -0.81818175 -0.75757575 -0.6969695  -0.6363635  -0.5757575  -0.5151515
#  -0.4545455  -0.39393926 -0.33333325 -0.27272725 -0.21212101 -0.151515
#  -0.090909   -0.030303    0.030303    0.09090924  0.15151525  0.21212125
#   0.2727275   0.3333335   0.3939395   0.4545455   0.5151515   0.57575774
#   0.63636374  0.69696975  0.757576    0.818182    0.878788    0.939394
#   1.          1.060606    1.121212    1.1818185   1.2424245   1.3030305
#   1.3636365   1.4242425   1.4848485   1.5454545   1.606061    1.666667
# ...

# %%
sess = tf.Session(graph=g)
sess.close()

# %%
g2 = tf.Graph()

# %%
sess = tf.InteractiveSession()
x.eval()
# Out:
# array([-3.        , -2.939394  , -2.878788  , -2.8181818 , -2.7575758 ,
#        -2.6969697 , -2.6363635 , -2.5757575 , -2.5151515 , -2.4545455 ,
#        -2.3939395 , -2.3333333 , -2.2727273 , -2.2121212 , -2.151515  ,
#        -2.090909  , -2.030303  , -1.969697  , -1.9090909 , -1.8484848 ,
#        -1.7878788 , -1.7272727 , -1.6666666 , -1.6060605 , -1.5454545 ,
#        -1.4848485 , -1.4242424 , -1.3636363 , -1.3030303 , -1.2424242 ,
#        -1.1818181 , -1.121212  , -1.060606  , -1.        , -0.939394  ,
#        -0.87878776, -0.81818175, -0.75757575, -0.6969695 , -0.6363635 ,
#        -0.5757575 , -0.5151515 , -0.4545455 , -0.39393926, -0.33333325,
#        -0.27272725, -0.21212101, -0.151515  , -0.090909  , -0.030303  ,
#         0.030303  ,  0.09090924,  0.15151525,  0.21212125,  0.2727275 ,
#         0.3333335 ,  0.3939395 ,  0.4545455 ,  0.5151515 ,  0.57575774,
#         0.63636374,  0.69696975,  0.757576  ,  0.818182  ,  0.878788  ,
# ...

# %%
# find shape of tensor
print(x.get_shape())

#OR
print(x.get_shape().as_list())
# Out:
# (100,)
# [100]

# %%
# The 1 dimensional gaussian takes two parameters, the mean value, and the standard deviation, which is denoted by sigma.
mean = 0.0
sigma = 1.0

z = (tf.exp(tf.negative(tf.pow(x - mean, 2.0) /
                   (2.0 * tf.pow(sigma, 2.0)))) *
     (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))

# %%
res = z.eval()
plt.plot(res)

# %%
# store the number of values in Gaussian curve.
ksize = z.get_shape().as_list()[0]

# multiply to get a 2d gaussian
z_2d = tf.matmul(tf.reshape(z, [ksize, 1]), tf.reshape(z, [1, ksize]))

# Execute graph
plt.imshow(z_2d.eval())

# %%
# load an image, get skimage by pip installing "scikit-image".
from skimage import data
img = data.camera().astype(np.float32)
plt.imshow(img, cmap='gray')
print(img.shape)
# Out:
# (512, 512)

# %%
#use the tensorflow reshape function:
img_4d = tf.reshape(img, [1, img.shape[0], img.shape[1], 1])
print(img_4d)
# Out:
# Tensor("Reshape_2:0", shape=(1, 512, 512, 1), dtype=float32)

# %%
print(img_4d.get_shape())
print(img_4d.get_shape().as_list())
# Out:
# (1, 512, 512, 1)
# [1, 512, 512, 1]

# %%
# Reshape the 2d kernel to tensorflow's required 4d format: H x W x I x O
z_4d = tf.reshape(z_2d, [ksize, ksize, 1, 1])
print(z_4d.get_shape().as_list())
# Out:
# [100, 100, 1, 1]

# %%
convolved = tf.nn.conv2d(img_4d, z_4d, strides=[1, 1, 1, 1], padding='SAME')
res = convolved.eval()
print(res.shape)
# Out:
# (1, 512, 512, 1)

# %%
#convert this back to the original shape.
plt.imshow(np.squeeze(res), cmap='gray')

# Or specify the exact dimensions we want to visualize:
plt.imshow(res[0, :, :, 0], cmap='gray')

# %%
xs = tf.linspace(-3.0, 3.0, ksize)

# %%
ys = tf.sin(xs)
plt.figure()
plt.plot(ys.eval())

# %%
ys = tf.reshape(ys, [ksize, 1])

# %%
ones = tf.ones((1, ksize))
wave = tf.matmul(ys, ones)
plt.imshow(wave.eval(), cmap='gray')

# %%
gabor = tf.multiply(wave, z_2d)
plt.imshow(gabor.eval(), cmap='gray')

# %%
# This is a placeholder which will become part of the tensorflow graph
img = tf.placeholder(tf.float32, shape=[None, None], name='img')


# reshape the 2d image to a 3-d tensor
# expand dims, which adds a singleton dimension at the axis specified 
# reshape H x W image to include a channel dimension of 1
# new dimensions will end up being: H x W x 1
img_3d = tf.expand_dims(img, 2)
dims = img_3d.get_shape()
print(dims)

# again to get: 1 x H x W x 1
img_4d = tf.expand_dims(img_3d, 0)
print(img_4d.get_shape().as_list())

# create another set of placeholders for Gabor's parameters:
mean = tf.placeholder(tf.float32, name='mean')
sigma = tf.placeholder(tf.float32, name='sigma')
ksize = tf.placeholder(tf.int32, name='ksize')

# edo the entire set of operations we've done to convolve
# image, except with placeholders
x = tf.linspace(-3.0, 3.0, ksize)
z = (tf.exp(tf.negative(tf.pow(x - mean, 2.0) /
                   (2.0 * tf.pow(sigma, 2.0)))) *
      (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))
z_2d = tf.matmul(
  tf.reshape(z, tf.stack([ksize, 1])),
  tf.reshape(z, tf.stack([1, ksize])))
ys = tf.sin(x)
ys = tf.reshape(ys, tf.stack([ksize, 1]))
ones = tf.ones(tf.stack([1, ksize]))
wave = tf.matmul(ys, ones)
gabor = tf.multiply(wave, z_2d)
gabor_4d = tf.reshape(gabor, tf.stack([ksize, ksize, 1, 1]))

# convolve the two:
convolved = tf.nn.conv2d(img_4d, gabor_4d, strides=[1, 1, 1, 1], padding='SAME', name='convolved')
convolved_img = convolved[0, :, :, 0]
# Out:
# (?, ?, 1)
# [1, None, None, 1]

# %%
res = convolved_img.eval(feed_dict={
    img: data.camera(), mean:0.0, sigma:1.0, ksize:100})
plt.imshow(res, cmap='gray')

# %%
res = convolved_img.eval(feed_dict={
    img: data.camera(),
    mean: 0.0,
    sigma: 0.5,
    ksize: 32
  })
plt.imshow(res, cmap='gray')
